# %%
# !pip install builtwith
# Out:
# Collecting builtwith
#   Downloading builtwith-1.3.4.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from builtwith) (1.17.0)
# Building wheels for collected packages: builtwith
#   Building wheel for builtwith (setup.py) ... done
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36077 sha256=5f04b0532dd305eea0bc264d3a3c60b935d00fb3fb06135295e6e5d14eec969b
#   Stored in directory: /root/.cache/pip/wheels/7f/2d/b2/606e3df914d4aeeab99c4a4e3e9a61673d2293c2e346db00c8
# Successfully built builtwith
# Installing collected packages: builtwith
# Successfully installed builtwith-1.3.4

# %%
BASE_URL = "https://pta.trunojoyo.ac.id/c_search/byprod"

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
import sys
import re

MAX_PAGE_LIMIT = 5  # misal batasi agar tidak terlalu banyak halaman
PRODI_FATEK = {
    9: "Teknik Industri",
    10: "Teknik Informatika",
    11: "Manajemen Informatika",
    19: "Teknik Multimedia Dan Jaringan",
    20: "Mekatronika",
    23: "Teknik Elektro",
    31: "Sistem Informasi",
    32: "Teknik Mesin",
    33: "Teknik Mekatronika"
}

HEADERS = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'}

def extract_after_colon(text):
    if text and ':' in text:
        return text.split(':', 1)[1].strip()
    return text.strip() if text else "N/A"

def pta_fatek_fast(BASE_URL):
    start_time = time.time()

    data = {
        "id": [], "penulis": [], "judul": [], "abstrak_id": [],
        "abstrak_en": [], "pembimbing_pertama": [], "pembimbing_kedua": [], "prodi": []
    }

    for prodi_id, prodi_name in PRODI_FATEK.items():
        print(f"\n🔹 Scraping program: {prodi_name}")
        try:
            max_page = min(get_max_page(prodi_id, BASE_URL), MAX_PAGE_LIMIT)
        except:
            max_page = 1
        for j in range(1, max_page + 1):
            url = f"{BASE_URL}/{prodi_id}/{j}"
            try:
                r = requests.get(url, headers=HEADERS, timeout=10)
                r.raise_for_status()
                soup = BeautifulSoup(r.content, "html.parser")
                jurnals = soup.select('li[data-cat="#luxury"]')
            except Exception as e:
                print(f"⚠️ Gagal ambil halaman {j} prodi {prodi_name}: {e}")
                continue

            for jurnal in jurnals:
                try:
                    link_keluar = jurnal.select_one('a.gray.button')['href']
                    id_match = re.search(r"/detail/(\d+)", link_keluar)
                    pta_id = id_match.group(1) if id_match else None

                    resp = requests.get(link_keluar, headers=HEADERS, timeout=10)
                    resp.raise_for_status()
                    isi = BeautifulSoup(resp.content, "html.parser").select_one('div#content_journal')

                    judul = isi.select_one('a.title').text.strip() if isi and isi.select_one('a.title') else "N/A"

                    penulis = extract_after_colon(isi.find(string=re.compile("Penulis"))) if isi else "N/A"
                    pembimbing_pertama = extract_after_colon(isi.find(string=re.compile("Dosen Pembimbing I"))) if isi else "N/A"
                    pembimbing_kedua = extract_after_colon(isi.find(string=re.compile("Dosen Pembimbing II"))) if isi else "N/A"

                    paragraf = isi.select('p[align="justify"]') if isi else []
                    abstrak_id = paragraf[0].get_text(strip=True) if len(paragraf) > 0 else "N/A"
                    abstrak_en = paragraf[1].get_text(strip=True) if len(paragraf) > 1 else "N/A"

                    data["id"].append(pta_id)
                    data["penulis"].append(penulis)
                    data["judul"].append(judul)
                    data["abstrak_id"].append(abstrak_id)
                    data["abstrak_en"].append(abstrak_en)
                    data["pembimbing_pertama"].append(pembimbing_pertama)
                    data["pembimbing_kedua"].append(pembimbing_kedua)
                    data["prodi"].append(prodi_name)

                except Exception as e:
                    print(f"⚠️ Gagal scrape jurnal: {e}")
            time.sleep(0.5)  # delay kecil agar tidak dianggap bot
            sys.stdout.write(f"\rHalaman {j}/{max_page} selesai")
            sys.stdout.flush()

    df = pd.DataFrame(data)
    df.to_csv("pta_fatek_fast.csv", index=False, encoding="utf-8-sig")

    elapsed = int(time.time() - start_time)
    jam, sisa = divmod(elapsed, 3600)
    menit, detik = divmod(sisa, 60)

    print(f"\n✅ Selesai! Total entri: {len(df)} | Waktu: {jam}j {menit}m {detik}s")
    return df

# %%
pta_fatek_fast(BASE_URL)
# Out:
# 🔹 Scraping program: Teknik Industri
# Halaman 1/1 selesai
# 🔹 Scraping program: Teknik Informatika
# Halaman 1/1 selesai
# 🔹 Scraping program: Manajemen Informatika
# Halaman 1/1 selesai
# 🔹 Scraping program: Teknik Multimedia Dan Jaringan
# Halaman 1/1 selesai
# 🔹 Scraping program: Mekatronika
# Halaman 1/1 selesai
# 🔹 Scraping program: Teknik Elektro
# Halaman 1/1 selesai
# 🔹 Scraping program: Sistem Informasi
# Halaman 1/1 selesai
# 🔹 Scraping program: Teknik Mesin
# Halaman 1/1 selesai
# 🔹 Scraping program: Teknik Mekatronika
# Halaman 1/1 selesai
# ✅ Selesai! Total entri: 35 | Waktu: 0j 3m 14s
#               id                           penulis  \
# 0   080421100005  Siliwangi Fitra Rachmawanto S.T.
# 1   080421100087                      AHMAD MAS'UD
# 2   080421100019                 Yulianto Fauzanta
# 3   080421100055                 M Mundir Muhlisin
# 4   080421100046                          Muhibbin
# 5   040411100468                A.Ubaidillah S.Kom
# 6   040411100476               M. Basith Ardianto,
# 7   040411100480             Akhmad Suyandi, S.Kom
# 8   070411100070                   Heri Supriyanto
# 9   080411100115              Septian Rahman Hakim
# 10  070451100021              Elky Lilik Misdayani
# 11  070451100037                    lu'luul maknun
# 12  070451100039            Megawati Bukhori Putri
# 13  070451100011  Andika Syarifuddin Parmana Putra
# 14  070451100015                Deka Pranaristanto
# 15  100471100002                    Achmad Husaini
# 16  100471100034             FIKRI MUJADDIDI ALHAK
# 17  100471100001              artika frida nirmala
# 18  100471100036                       Ahmad Rivai
# 19  100471100032                       Idrus Tamam
# 20  100461100003                 Moh. Amin Wahyudi
# 21  100461100006                       DWI NUGROHO
# 22  100461100007               Rezky Septian Akbar
# 23  100461100005                   Rio Tri Susanto
# 24  110461100003           Moh. Iswahyudinorrahman
# 25  130431100051                      Achmad Faidi
# 26  130431100041                Dandi Fathur Rohim
# 27  130431100087       Reynanda Bagus Widyo Astomo
# 28  130431100025       Moh.Nazilus Sa’din Romdloni
# 29  130431100071                Fajar Dwima Wijaya
# 30  160491200026             Mochamad Izar Bahroni
# 31  160491200023                        Moch Zaini
# 32  160491200027               Mohammad Syafruddin
# 33  160491200028        Khanif Khoirul Umam, A.Md.
# 34  160491200025              Achmad Ayubal Ansori
#
#                                                 judul  \
# 0   OPTIMASI PEMILIHAN PORTOFOLIO SAHAM PERUSAHAAN...
# 1   PERANCANGAN TATA LETAK FASILITAS LANTAI PRODUK...
# 2   PERUMUSAN STRATEGI BISNIS UD. BUDI JAYA BANGKA...
# 3   USULAN PERBAIKAN UTILITAS RESOURCES PADA LANTA...
# 4   Peningkatan Kepuasan Masyarakat Terhadap Pelay...
# 5   PERANCANGAN DAN IMPLEMENTASI SISTEM DATABASE \...
# 6   APLIKASI KONTROL DAN MONITORING JARINGAN KOMPU...
# 7   RANCANG BANGUN APLIKASI PROXY SERVER UNTUK\r\n...
# 8   SISTEM PENDUKUNG KEPUTUSAN OPTIMASI PENJADWALA...
# 9   SISTEM AUGMENTED REALITY ANIMASI BENDA BERGERA...
# 10  SISTEM INFORMASI PERUSAHAAN OTOBUS SUMBER KENC...
# 11  SISTEM INFORMASI GEOGRAFIS PEMETAAN POTENSI OB...
# 12         SISTEM INFORMASI PSIKOTES BERBASIS DEKSTOP
# 13  Perancangan Dan Pembuatan Sistem Informasi Man...
# 14  SISTEM INFORMASI PEMESANAN RUMAH BERBASIS WEB ...
# 15  Elektronik Pemilihan Kepala Desa Menggunakan M...
# 16                      DIGITAL INFORMATION ASSISTANT
# 17  perancangan aplikasi female e-healthy untuk de...
# 18  SISTEM INFORMASI TUGAS AKHIR PRODI TEKNIK MULT...
# 19  APLIKASI PETA WISATA DIGITAL BANGKALAN DENGAN\...
# 20  PERANCANGAN INJECTOR CLEANER DAN TESTER PADA S...
# 21  PROTOTYPE ALAT PEMBERI PAKAN\r\nAYAM PETELUR O...
# 22             pengukur tinggi badan berbasis arduino
# 23  PEMODELAN SISTEM INFORMASI KETERSEDIAAN RUANG ...
# 24  Desain Sistem pengendali Pintu otomatis Menggu...
# 25  RANCANG BANGUN PENGATUR TEGANGAN OTOMATIS PADA...
# 26          SMART GARBAGE BERBASIS INTERNET OF THINGS
# 27  Perancangan dan Pembuatan Stop Kontak Berbasis...
# 28  PROTOTYPE SISTEM MONITORING DAN PENGENDALIAN P...
# 29  Rancang Bangun Sistem Keamanan Parkir Berbasis...
# 30  Kestabilan Autonomous Quadcopter Dengan Kontro...
# 31  perancangan dan pembuatan sistem rem elektrik ...
# 32  Pengatur Kerapatan Kertas Pada Alat Penggulung...
# 33  IMPLEMENTASI ALGORITMA MAZE MAPPING PENCARIAN ...
# 34  Alat Pengering Rumput Laut Menggunakan Metode ...
#
#                                            abstrak_id  \
# 0   Portofolio adalah sekumpulan saham yang dimili...
# 1   PT. ABC merupakan perusahaan yang bergerak dib...
# 2   Bangkalan merupakan salah satu kabupaten yang ...
# 3   Simulasi adalah duplikasi atau abstraksi dari ...
# 4   Kepuasan adalah tingkat perasaan seseorang ter...
# 5   Sistem  informasi  akademik  (SIAKAD) merupaka...
# 6   Berjalannya koneksi jaringan komputer dengan l...
# 7   Web server adalah sebuah perangkat lunak serve...
# 8   Penjadwalan  kuliah  di  Perguruan  Tinggi  me...
# 9   Seiring perkembangan teknologi yang ada diduni...
# 10  Sistem informasi pengolahan data yang dibutuhk...
# 11  Abstrak\r\nPerkembangan teknologi di berbagai ...
# 12  Abstrak\r\nPerkembangan teknologi di berbagai ...
# 13  Abstrak\r\n\r\nSistem Informasi Manajemen Data...
# 14  Sistem pemesanan atau profil tentang PT. PROPI...
# 15  ABSTRAK\r\n\r\nPerkembangan teknologi informas...
# 16  Media informasi kini perkembangannya sangat pe...
# 17  Kanker serviks merupakan kanker terganas yang ...
# 18  Prodi teknik Multimedia dan Jaringan adalah sa...
# 19  Pemerintah Indonesia telah berupaya meningkatk...
# 20  ABSTRAK\r\nSepeda motor menggunakan sistem inj...
# 21  Peternakan merupakan salah satu bidang usaha y...
# 22  Perkembangan ilmu pengetahuan teknologi yang m...
# 23  Pengaturan parkir yang sampai saat ini masih b...
# 24  Pada zaman globalisasi mendorong teknologi unt...
# 25  Tegangan yang tidak stabil dapat merusak peran...
# 26  Sampah di Indonesia merupakan suatu masalah ya...
# 27  Pengunaan perangkat elektris dalam kehidupan s...
# 28  Indonesia merupakan negara dengan curah hujan ...
# 29  Sistem pengelolaan tempat parkir pada saat ini...
# 30  Unmanned Aerial Vehicle (UAV) memiliki banyak ...
# 31  Kendaraan merupakan suatu alat yang banyak dig...
# 32  PT PAKERIN adalah salah satu pabrik kertas ter...
# 33  Robot shortest path merupakan jenis robot yang...
# 34  Rumput laut merupakan tumbuhan laut yang banya...
#
#                                            abstrak_en  \
# 0   Portofolio is a collection of stock owned by i...
# 1   PT. ABC is a company engaged in the manufactur...
# 2   Bangkalan is one of the districts that have th...
# 3   Simulation is a duplication or abstraction of ...
# 4   Satisfaction is feeling level of someone to se...
# 5   Academic information systems (SIAKAD) is an in...
# 6                                                   -
# 7   Web server is a server software functioning to...
# 8   Scheduling  courses  in  universities  is  a  ...
# 9   As the development of technology existing in t...
# 10  Data processing information systems needed by ...
# 11  Abstract\r\nData processing systems required b...
# 12  Abstract\r\nTechnological developments in vari...
# 13  Abstract\r\n\r\nData Management Information Sy...
# 14  Ordering system or the profile of PT. MAIN WIR...
# 15  ABSTRACT\r\n\r\nThe development of information...
# 16  Media information is now very rapid developmen...
# 17  Cervical cancer is a vicious cancer caused by ...
# 18  Multimedia and Network engineering is one of t...
# 19  The Indonesian government has worked to increa...
# 20  ABSTRACT\r\nMotorcycle injection system is cur...
# 21  Livestock is one of the promising areas of bus...
# 22  The development of modern technology science h...
# 23  Mostly parking arrangement was done manually u...
# 24  At globalization epoch push technology to rapi...
# 25  Unstable voltages can damage electronic device...
# 26  Trash is one of serious prroblems in Indonesi....
# 27  The use of electrical devices in everyday life...
# 28  Indonesia known as the country with heavy rain...
# 29  Parking management system at this time is stil...
# 30  Unmanned Aerial Vehicle (UAV) has many uses, i...
# 31  Vehicle is a tool that is widely used by human...
# 32  PT PAKERIN is one of the largest paper mills i...
# 33  Shortest path robot is a type of robot that is...
# 34  Seaweed is a marine plant widely cultivated by...
#
#                     pembimbing_pertama                     pembimbing_kedua  \
# 0      Heri Awalul Ilhamsah S.T., M.T.   Retno Indriartiningtias S.T., M.T.
# 1         SABARUDIN AKHMAD, S.T., M.T.           SUGENG PURWOKO, S.T., M.T.
# 2            Fitri Agustina, S.T., M.T   Retno Indriartiningtias, S.T., M.T
# 3                        Mu'alim ST MT                 Sugeng Purwoko ST MT
# 4                       Rahmad Hidayat              Retno Indriartiningtias
# 5                     Budi Setyono M.T                         Hermawan S.T
# 6                Drs. Budi Soesilo, MT                        Koko Joni, ST
# 7               Drs. Budi Soesilo, M.T                     Hermawan, ST, MT
# 8                 Mulaab, S.Si., M.Kom            Firli Irhamni, ST., M.Kom
# 9        Arik Kurniawati, S.Kom., M.T.                 Haryanto, S.T., M.T.
# 10         Fitri Damayanti,S.Kom,M.Kom
# 11                 Aeri Rahmad,S.T,M.T                                    -
# 12    Yeni Kustianingsih, S.Kom, M.Kom                                    -
# 13                  Sri Herawati,S.Kom                   Sri Herawati,S.Kom
# 14          Budi Dwi Satoto S.T, M.Kom           Budi Dwi Satoto S.T, M.Kom
# 15               Aeri Rachmad, ST. MT.
# 16               AERI RACHMAD, ST., MT
# 17                 Aeri Rachmad ST, MT
# 18              Riza Alfita. S.T.,M.T.                                    -
# 19             Aeri Rachmad, S.T.,M. T
# 20          Hairil Budiarto, S.T., MT.
# 21         Muhammad Fuad, S.Kom. , MT.         Mirza Pramudia, ST. , M.Eng.
# 22  Ahmad Sahru Romadhon, S.Kom., M.T.
# 23           Muhammad Latif, S.T., M.T
# 24  ahmad Sahru Romadhon, S.KOM., M.T.
# 25             Koko Joni. S.T., M.Eng.  Achmad Fiqhi Ibadillah, S.T., M.Sc.
# 26                 Haryanto. S.T., M.T               Koko Joni. S.T., M.Eng
# 27
# 28                     Haryanto,ST,.MT                   Riza Alfita,ST,.MT
# 29          Diana Rahmawati, S.T., M.T        Kunto Aji Wibisono, S.T., M.T
# 30            Sri Wahyuni, S.Kom., M.T             Faikul Umam, S.Kom., M.T
# 31             Hairil Budiarto., ST.MT              Faikul Umam., S.Kom.,MT
# 32             Faikul Umam S.Kom., M.T     Ahmad Sahru Romadhon S.Kom., M.T
# 33           Sri Wahyuni, S.Kom., M.T.           Hairil Budiarto, S.T.,M.T.
# 34           Ahmad Sahru R.,S.Kom.,M.T             Hairil Budiarto S.T.,M.T
#
#                              prodi
# 0                  Teknik Industri
# 1                  Teknik Industri
# 2                  Teknik Industri
# 3                  Teknik Industri
# 4                  Teknik Industri
# 5               Teknik Informatika
# 6               Teknik Informatika
# 7               Teknik Informatika
# 8               Teknik Informatika
# 9               Teknik Informatika
# 10           Manajemen Informatika
# 11           Manajemen Informatika
# 12           Manajemen Informatika
# 13           Manajemen Informatika
# 14           Manajemen Informatika
# 15  Teknik Multimedia Dan Jaringan
# 16  Teknik Multimedia Dan Jaringan
# 17  Teknik Multimedia Dan Jaringan
# 18  Teknik Multimedia Dan Jaringan
# 19  Teknik Multimedia Dan Jaringan
# 20                     Mekatronika
# 21                     Mekatronika
# 22                     Mekatronika
# 23                     Mekatronika
# 24                     Mekatronika
# 25                  Teknik Elektro
# 26                  Teknik Elektro
# 27                  Teknik Elektro
# 28                  Teknik Elektro
# 29                  Teknik Elektro
# 30              Teknik Mekatronika
# 31              Teknik Mekatronika
# 32              Teknik Mekatronika
# 33              Teknik Mekatronika
# 34              Teknik Mekatronika
